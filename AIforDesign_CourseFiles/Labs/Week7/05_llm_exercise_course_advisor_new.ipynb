# %%
# This Python environment comes with many helpful analytics libraries installed
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "/content" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 80+GB to the current directory (/content)
# You can also write temporary files to /content, but they won't be saved outside of the current session

# %% [markdown]
# # Exercise: Course advisor chatbot
#
# We can automate the collection of user prompts and assistant responses to build a Course Advisor Bot.
#
# The bot includes two agents: one for conducting user interviews and another for course recommendations.
#
# By combining multiple agents, we can enhance output stability and facilitate further optimization.
#
# System Prompt: Sets the context and rules for the chatbot, defining its role and behavior.
# User Prompt: The input or question provided by the user to the chatbot.

# %%
# set environment and library (1 point)

# %%
# define useful functions such as sending message to Azure openai server (2 points)

# %%
# define the first AI agent to do user interviews. you should design the system prompts, agent behaviour and record the chat history (4 points)
# let AI agent ask questions to users
# keep convsersarion until user say "exit"
# this is the sample code fo

def multi_chat():
    # design system prompts
    context = [
        {'role': 'system', 'content': """
        design your prompts
        """}
    ]

    print("Chat started. Type 'Exit' to end the conversation.\n")

    while True:
        user_input = input("User: ")
        if user_input.strip().lower() == 'exit':
            print("Ending conversation.")
            break

        # record the user's input
        # get the response from the first AI agent
        # record the LLM's response
        # print LLM's response

multi_chat()

# %%
# Do course recommendations (3 points)
#Summarize and use the user information collected by the first AI agent.
#Provide tailored course recommendations.
#Set behavior to avoid asking questions and limit the total number of courses suggested.

messages = [{'role':'system',
 'content':"""
 """}]

#get response from the second AI agent
#print the final response
